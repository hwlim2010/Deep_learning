# %%
# Module Import

from __future__ import print_function
from torch import nn, optim, cuda
from torch.utils import data
from torchvision import datasets, transforms
import torch.nn.functional as F
import time
import matplotlib.pyplot as plt

# %%
## Google Drive Mount 

from google.colab import drive
drive.mount('/content/hw_drive')


## Trainig Setup

batch_size = 64
device = 'cuda' if cuda.is_available() else 'cpu'
print(f'Training MNIST Model on {device}\n{"="*44}')


## MNIST dataset Download 
train_dataset = datasets.MNIST(root='/content/hw_drive/My Drive/mai1/mnist_data/', 
                              train=True, 
                              transform=transforms.ToTensor(),
                              download=True)
test_dataset = datasets.MNIST(root='/content/hw_drive/My Drive/mai1/mnist_data/',
                             train=False,
                             transform=transforms.ToTensor())

## Data loader
train_loader = data.DataLoader(dataset=train_dataset,
                               batch_size=batch_size,
                               shuffle=True)
test_loader = data.DataLoader(dataset=test_dataset,
                              batch_size=batch_size,
                              shuffle=False)
# Out:
# Mounted at /content/hw_drive
# Training MNIST Model on cuda
# ============================================

# %%
## Network Architecture Definition

class Net(nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    self.l1 = nn.Linear(784, 520)
    self.l2 = nn.Linear(520, 320)
    self.l3 = nn.Linear(320, 240)
    self.l4 = nn.Linear(240, 120)
    self.l5 = nn.Linear(120, 10)

  def forward(self, x):
    x = x.view(-1, 784)   #Flatten the data ( n, 1, 28, 28 ) -> (n, 784)
    x = F.relu(self.l1(x))
    x = F.relu(self.l2(x))
    x = F.relu(self.l3(x))
    x = F.relu(self.l4(x))
    return self.l5(x)

## Network Load

model = Net()
model.to(device)
# Out:
# Net(
#   (l1): Linear(in_features=784, out_features=520, bias=True)
#   (l2): Linear(in_features=520, out_features=320, bias=True)
#   (l3): Linear(in_features=320, out_features=240, bias=True)
#   (l4): Linear(in_features=240, out_features=120, bias=True)
#   (l5): Linear(in_features=120, out_features=10, bias=True)
# )

# %%
## Training Setup

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.5)

# %%
## Train Function 

def train(epoch):
  model.train()
  for batch_idx, (data, target) in enumerate(train_loader):
    data, target = data.to(device), target.to(device)
    optimizer.zero_grad()
    output = model(data)
    loss = criterion(output, target)
    loss.backward()
    optimizer.step()
    if batch_idx % 10 == 0:
      print('Train Epoch : {} | Batch Status : {}/{} ({:.0f}%) | Loss : {:.6f}'.format(
          epoch, batch_idx*len(data), len(train_loader.dataset),
          100. * batch_idx / len(train_loader), loss.item()))


## Test Function

def test():
  model.eval()
  test_loss = 0
  correct = 0
  for data, target in test_loader:
    data, target = data.to(device), target.to(device)
    output = model(data)

    # sum up batch loss
    test_loss += criterion(output, target).item()

    # get the index of the max
    pred = output.data.max(1, keepdim=True)[1]
    correct += pred.eq(target.data.view_as(pred)).cpu().sum()

  test_loss /= len(test_loader.dataset)
  print(f'==================\nTest set: Average loss : {test_loss:.4f}, Accuracy : {correct}/{len(test_loader.dataset)}'
        f'({100. * correct / len(test_loader.dataset):.0f}%)')

# %%
## Main

if __name__ == '__main__':
 
  since = time.time()
  for epoch in range(1, 10):
    epoch_start = time.time()
    train(epoch)
    m, s = divmod(time.time() - epoch_start, 60)
    print(f'Training time: {m:.0f}m {s:.0f}s')
    
    test()
    m, s = divmod(time.time() - epoch_start, 60)
    print(f'Tesing time: {m:.0f}m {s:.0f}s')

  m, s = divmod(time.time() - epoch_start, 60)
  print(f'Total time : {m:.0f}m {s: .0f}s \nModel was trained on {device}!')
# Out:
# Train Epoch : 1 | Batch Status : 0/60000 (0%) | Loss : 2.303060
# Train Epoch : 1 | Batch Status : 640/60000 (1%) | Loss : 2.302449
# Train Epoch : 1 | Batch Status : 1280/60000 (2%) | Loss : 2.299678
# Train Epoch : 1 | Batch Status : 1920/60000 (3%) | Loss : 2.299911
# Train Epoch : 1 | Batch Status : 2560/60000 (4%) | Loss : 2.301847
# Train Epoch : 1 | Batch Status : 3200/60000 (5%) | Loss : 2.297141
# Train Epoch : 1 | Batch Status : 3840/60000 (6%) | Loss : 2.299596
# Train Epoch : 1 | Batch Status : 4480/60000 (7%) | Loss : 2.299692
# Train Epoch : 1 | Batch Status : 5120/60000 (9%) | Loss : 2.304871
# Train Epoch : 1 | Batch Status : 5760/60000 (10%) | Loss : 2.301354
# Train Epoch : 1 | Batch Status : 6400/60000 (11%) | Loss : 2.300351
# Train Epoch : 1 | Batch Status : 7040/60000 (12%) | Loss : 2.297032
# Train Epoch : 1 | Batch Status : 7680/60000 (13%) | Loss : 2.298703
# Train Epoch : 1 | Batch Status : 8320/60000 (14%) | Loss : 2.294399
# Train Epoch : 1 | Batch Status : 8960/60000 (15%) | Loss : 2.300026
# Train Epoch : 1 | Batch Status : 9600/60000 (16%) | Loss : 2.297618
# Train Epoch : 1 | Batch Status : 10240/60000 (17%) | Loss : 2.299756
# Train Epoch : 1 | Batch Status : 10880/60000 (18%) | Loss : 2.296494
# Train Epoch : 1 | Batch Status : 11520/60000 (19%) | Loss : 2.294437
# Train Epoch : 1 | Batch Status : 12160/60000 (20%) | Loss : 2.295207
# Train Epoch : 1 | Batch Status : 12800/60000 (21%) | Loss : 2.294657
# Train Epoch : 1 | Batch Status : 13440/60000 (22%) | Loss : 2.289141
# Train Epoch : 1 | Batch Status : 14080/60000 (23%) | Loss : 2.298921
# Train Epoch : 1 | Batch Status : 14720/60000 (25%) | Loss : 2.298311
# Train Epoch : 1 | Batch Status : 15360/60000 (26%) | Loss : 2.300081
# Train Epoch : 1 | Batch Status : 16000/60000 (27%) | Loss : 2.292534
# Train Epoch : 1 | Batch Status : 16640/60000 (28%) | Loss : 2.294968
# Train Epoch : 1 | Batch Status : 17280/60000 (29%) | Loss : 2.288711
# Train Epoch : 1 | Batch Status : 17920/60000 (30%) | Loss : 2.289055
# Train Epoch : 1 | Batch Status : 18560/60000 (31%) | Loss : 2.291329
# Train Epoch : 1 | Batch Status : 19200/60000 (32%) | Loss : 2.295155
# Train Epoch : 1 | Batch Status : 19840/60000 (33%) | Loss : 2.294395
# Train Epoch : 1 | Batch Status : 20480/60000 (34%) | Loss : 2.290292
# Train Epoch : 1 | Batch Status : 21120/60000 (35%) | Loss : 2.286288
# Train Epoch : 1 | Batch Status : 21760/60000 (36%) | Loss : 2.292777
# Train Epoch : 1 | Batch Status : 22400/60000 (37%) | Loss : 2.292078
# Train Epoch : 1 | Batch Status : 23040/60000 (38%) | Loss : 2.290659
# Train Epoch : 1 | Batch Status : 23680/60000 (39%) | Loss : 2.285881
# Train Epoch : 1 | Batch Status : 24320/60000 (41%) | Loss : 2.279880
# Train Epoch : 1 | Batch Status : 24960/60000 (42%) | Loss : 2.287681
# Train Epoch : 1 | Batch Status : 25600/60000 (43%) | Loss : 2.290722
# Train Epoch : 1 | Batch Status : 26240/60000 (44%) | Loss : 2.281760
# Train Epoch : 1 | Batch Status : 26880/60000 (45%) | Loss : 2.281043
# Train Epoch : 1 | Batch Status : 27520/60000 (46%) | Loss : 2.279324
# Train Epoch : 1 | Batch Status : 28160/60000 (47%) | Loss : 2.282885
# Train Epoch : 1 | Batch Status : 28800/60000 (48%) | Loss : 2.290456
# Train Epoch : 1 | Batch Status : 29440/60000 (49%) | Loss : 2.285562
# Train Epoch : 1 | Batch Status : 30080/60000 (50%) | Loss : 2.269920
# Train Epoch : 1 | Batch Status : 30720/60000 (51%) | Loss : 2.273809
# Train Epoch : 1 | Batch Status : 31360/60000 (52%) | Loss : 2.278002
# Train Epoch : 1 | Batch Status : 32000/60000 (53%) | Loss : 2.275502
# Train Epoch : 1 | Batch Status : 32640/60000 (54%) | Loss : 2.272206
# Train Epoch : 1 | Batch Status : 33280/60000 (55%) | Loss : 2.271139
# Train Epoch : 1 | Batch Status : 33920/60000 (57%) | Loss : 2.280300
# Train Epoch : 1 | Batch Status : 34560/60000 (58%) | Loss : 2.267406
# Train Epoch : 1 | Batch Status : 35200/60000 (59%) | Loss : 2.261006
# Train Epoch : 1 | Batch Status : 35840/60000 (60%) | Loss : 2.255298
# Train Epoch : 1 | Batch Status : 36480/60000 (61%) | Loss : 2.245412
# Train Epoch : 1 | Batch Status : 37120/60000 (62%) | Loss : 2.250627
# Train Epoch : 1 | Batch Status : 37760/60000 (63%) | Loss : 2.259465
# Train Epoch : 1 | Batch Status : 38400/60000 (64%) | Loss : 2.252550
# Train Epoch : 1 | Batch Status : 39040/60000 (65%) | Loss : 2.256475
# Train Epoch : 1 | Batch Status : 39680/60000 (66%) | Loss : 2.246627
# Train Epoch : 1 | Batch Status : 40320/60000 (67%) | Loss : 2.253738
# Train Epoch : 1 | Batch Status : 40960/60000 (68%) | Loss : 2.246291
# Train Epoch : 1 | Batch Status : 41600/60000 (69%) | Loss : 2.208758
# Train Epoch : 1 | Batch Status : 42240/60000 (70%) | Loss : 2.238034
# Train Epoch : 1 | Batch Status : 42880/60000 (71%) | Loss : 2.212108
# Train Epoch : 1 | Batch Status : 43520/60000 (72%) | Loss : 2.209494
# Train Epoch : 1 | Batch Status : 44160/60000 (74%) | Loss : 2.200681
# Train Epoch : 1 | Batch Status : 44800/60000 (75%) | Loss : 2.212817
# Train Epoch : 1 | Batch Status : 45440/60000 (76%) | Loss : 2.217393
# Train Epoch : 1 | Batch Status : 46080/60000 (77%) | Loss : 2.193333
# Train Epoch : 1 | Batch Status : 46720/60000 (78%) | Loss : 2.169800
# Train Epoch : 1 | Batch Status : 47360/60000 (79%) | Loss : 2.160955
# Train Epoch : 1 | Batch Status : 48000/60000 (80%) | Loss : 2.160528
# Train Epoch : 1 | Batch Status : 48640/60000 (81%) | Loss : 2.149946
# Train Epoch : 1 | Batch Status : 49280/60000 (82%) | Loss : 2.113619
# Train Epoch : 1 | Batch Status : 49920/60000 (83%) | Loss : 2.097988
# Train Epoch : 1 | Batch Status : 50560/60000 (84%) | Loss : 2.064947
# Train Epoch : 1 | Batch Status : 51200/60000 (85%) | Loss : 1.990618
# Train Epoch : 1 | Batch Status : 51840/60000 (86%) | Loss : 2.045838
# Train Epoch : 1 | Batch Status : 52480/60000 (87%) | Loss : 2.134119
# Train Epoch : 1 | Batch Status : 53120/60000 (88%) | Loss : 1.981564
# Train Epoch : 1 | Batch Status : 53760/60000 (90%) | Loss : 2.057420
# Train Epoch : 1 | Batch Status : 54400/60000 (91%) | Loss : 1.931219
# Train Epoch : 1 | Batch Status : 55040/60000 (92%) | Loss : 1.888101
# Train Epoch : 1 | Batch Status : 55680/60000 (93%) | Loss : 1.952964
# Train Epoch : 1 | Batch Status : 56320/60000 (94%) | Loss : 1.920121
# Train Epoch : 1 | Batch Status : 56960/60000 (95%) | Loss : 1.778315
# Train Epoch : 1 | Batch Status : 57600/60000 (96%) | Loss : 1.852961
# Train Epoch : 1 | Batch Status : 58240/60000 (97%) | Loss : 1.773903
# Train Epoch : 1 | Batch Status : 58880/60000 (98%) | Loss : 1.787056
# Train Epoch : 1 | Batch Status : 59520/60000 (99%) | Loss : 1.668325
# Training time: 0m 7s
# ==================
# Test set: Average loss : 0.0258, Accuracy : 5209/10000(52%)
# Tesing time: 0m 8s
# Train Epoch : 2 | Batch Status : 0/60000 (0%) | Loss : 1.599367
# Train Epoch : 2 | Batch Status : 640/60000 (1%) | Loss : 1.607920
# Train Epoch : 2 | Batch Status : 1280/60000 (2%) | Loss : 1.566732
# Train Epoch : 2 | Batch Status : 1920/60000 (3%) | Loss : 1.399758
# Train Epoch : 2 | Batch Status : 2560/60000 (4%) | Loss : 1.255005
# Train Epoch : 2 | Batch Status : 3200/60000 (5%) | Loss : 1.378138
# Train Epoch : 2 | Batch Status : 3840/60000 (6%) | Loss : 1.364664
# Train Epoch : 2 | Batch Status : 4480/60000 (7%) | Loss : 1.373171
# Train Epoch : 2 | Batch Status : 5120/60000 (9%) | Loss : 1.170121
# Train Epoch : 2 | Batch Status : 5760/60000 (10%) | Loss : 1.119691
# Train Epoch : 2 | Batch Status : 6400/60000 (11%) | Loss : 1.220800
# Train Epoch : 2 | Batch Status : 7040/60000 (12%) | Loss : 1.078453
# Train Epoch : 2 | Batch Status : 7680/60000 (13%) | Loss : 0.917175
# Train Epoch : 2 | Batch Status : 8320/60000 (14%) | Loss : 0.879995
# Train Epoch : 2 | Batch Status : 8960/60000 (15%) | Loss : 0.935204
# Train Epoch : 2 | Batch Status : 9600/60000 (16%) | Loss : 0.837228
# Train Epoch : 2 | Batch Status : 10240/60000 (17%) | Loss : 0.701629
# Train Epoch : 2 | Batch Status : 10880/60000 (18%) | Loss : 0.653981
# Train Epoch : 2 | Batch Status : 11520/60000 (19%) | Loss : 0.758748
# Train Epoch : 2 | Batch Status : 12160/60000 (20%) | Loss : 0.785408
# Train Epoch : 2 | Batch Status : 12800/60000 (21%) | Loss : 0.896974
# Train Epoch : 2 | Batch Status : 13440/60000 (22%) | Loss : 0.674247
# Train Epoch : 2 | Batch Status : 14080/60000 (23%) | Loss : 0.760119
# Train Epoch : 2 | Batch Status : 14720/60000 (25%) | Loss : 0.763915
# Train Epoch : 2 | Batch Status : 15360/60000 (26%) | Loss : 0.862443
# Train Epoch : 2 | Batch Status : 16000/60000 (27%) | Loss : 0.601242
# Train Epoch : 2 | Batch Status : 16640/60000 (28%) | Loss : 0.614589
# Train Epoch : 2 | Batch Status : 17280/60000 (29%) | Loss : 0.666720
# Train Epoch : 2 | Batch Status : 17920/60000 (30%) | Loss : 0.735757
# Train Epoch : 2 | Batch Status : 18560/60000 (31%) | Loss : 0.517158
# Train Epoch : 2 | Batch Status : 19200/60000 (32%) | Loss : 0.570697
# Train Epoch : 2 | Batch Status : 19840/60000 (33%) | Loss : 0.688704
# Train Epoch : 2 | Batch Status : 20480/60000 (34%) | Loss : 0.786111
# Train Epoch : 2 | Batch Status : 21120/60000 (35%) | Loss : 0.643776
# Train Epoch : 2 | Batch Status : 21760/60000 (36%) | Loss : 0.623167
# Train Epoch : 2 | Batch Status : 22400/60000 (37%) | Loss : 0.389781
# Train Epoch : 2 | Batch Status : 23040/60000 (38%) | Loss : 0.482269
# Train Epoch : 2 | Batch Status : 23680/60000 (39%) | Loss : 1.004630
# Train Epoch : 2 | Batch Status : 24320/60000 (41%) | Loss : 0.481027
# Train Epoch : 2 | Batch Status : 24960/60000 (42%) | Loss : 0.487875
# Train Epoch : 2 | Batch Status : 25600/60000 (43%) | Loss : 0.579381
# Train Epoch : 2 | Batch Status : 26240/60000 (44%) | Loss : 0.682652
# Train Epoch : 2 | Batch Status : 26880/60000 (45%) | Loss : 0.471641
# Train Epoch : 2 | Batch Status : 27520/60000 (46%) | Loss : 0.423870
# Train Epoch : 2 | Batch Status : 28160/60000 (47%) | Loss : 0.405273
# Train Epoch : 2 | Batch Status : 28800/60000 (48%) | Loss : 0.642129
# Train Epoch : 2 | Batch Status : 29440/60000 (49%) | Loss : 0.473045
# Train Epoch : 2 | Batch Status : 30080/60000 (50%) | Loss : 0.468193
# Train Epoch : 2 | Batch Status : 30720/60000 (51%) | Loss : 0.444114
# Train Epoch : 2 | Batch Status : 31360/60000 (52%) | Loss : 0.406438
# Train Epoch : 2 | Batch Status : 32000/60000 (53%) | Loss : 0.499921
# Train Epoch : 2 | Batch Status : 32640/60000 (54%) | Loss : 0.658863
# Train Epoch : 2 | Batch Status : 33280/60000 (55%) | Loss : 0.496833
# Train Epoch : 2 | Batch Status : 33920/60000 (57%) | Loss : 0.489520
# Train Epoch : 2 | Batch Status : 34560/60000 (58%) | Loss : 0.659686
# Train Epoch : 2 | Batch Status : 35200/60000 (59%) | Loss : 0.461093
# Train Epoch : 2 | Batch Status : 35840/60000 (60%) | Loss : 0.639991
# Train Epoch : 2 | Batch Status : 36480/60000 (61%) | Loss : 0.476382
# Train Epoch : 2 | Batch Status : 37120/60000 (62%) | Loss : 0.265301
# Train Epoch : 2 | Batch Status : 37760/60000 (63%) | Loss : 0.298421
# Train Epoch : 2 | Batch Status : 38400/60000 (64%) | Loss : 0.296355
# Train Epoch : 2 | Batch Status : 39040/60000 (65%) | Loss : 0.902097
# Train Epoch : 2 | Batch Status : 39680/60000 (66%) | Loss : 0.410941
# Train Epoch : 2 | Batch Status : 40320/60000 (67%) | Loss : 0.462955
# Train Epoch : 2 | Batch Status : 40960/60000 (68%) | Loss : 0.616089
# Train Epoch : 2 | Batch Status : 41600/60000 (69%) | Loss : 0.572365
# Train Epoch : 2 | Batch Status : 42240/60000 (70%) | Loss : 0.514445
# Train Epoch : 2 | Batch Status : 42880/60000 (71%) | Loss : 0.520570
# Train Epoch : 2 | Batch Status : 43520/60000 (72%) | Loss : 0.449053
# Train Epoch : 2 | Batch Status : 44160/60000 (74%) | Loss : 0.248305
# Train Epoch : 2 | Batch Status : 44800/60000 (75%) | Loss : 0.593338
# Train Epoch : 2 | Batch Status : 45440/60000 (76%) | Loss : 0.718644
# Train Epoch : 2 | Batch Status : 46080/60000 (77%) | Loss : 0.490135
# Train Epoch : 2 | Batch Status : 46720/60000 (78%) | Loss : 0.439405
# Train Epoch : 2 | Batch Status : 47360/60000 (79%) | Loss : 0.496205
# Train Epoch : 2 | Batch Status : 48000/60000 (80%) | Loss : 0.398923
# Train Epoch : 2 | Batch Status : 48640/60000 (81%) | Loss : 0.387675
# Train Epoch : 2 | Batch Status : 49280/60000 (82%) | Loss : 0.581136
# Train Epoch : 2 | Batch Status : 49920/60000 (83%) | Loss : 0.792958
# Train Epoch : 2 | Batch Status : 50560/60000 (84%) | Loss : 0.253092
# Train Epoch : 2 | Batch Status : 51200/60000 (85%) | Loss : 0.259818
# Train Epoch : 2 | Batch Status : 51840/60000 (86%) | Loss : 0.471620
# Train Epoch : 2 | Batch Status : 52480/60000 (87%) | Loss : 0.237963
# Train Epoch : 2 | Batch Status : 53120/60000 (88%) | Loss : 0.841275
# Train Epoch : 2 | Batch Status : 53760/60000 (90%) | Loss : 0.454343
# Train Epoch : 2 | Batch Status : 54400/60000 (91%) | Loss : 0.420475
# Train Epoch : 2 | Batch Status : 55040/60000 (92%) | Loss : 0.420553
# Train Epoch : 2 | Batch Status : 55680/60000 (93%) | Loss : 0.397933
# Train Epoch : 2 | Batch Status : 56320/60000 (94%) | Loss : 0.421486
# Train Epoch : 2 | Batch Status : 56960/60000 (95%) | Loss : 0.669012
# Train Epoch : 2 | Batch Status : 57600/60000 (96%) | Loss : 0.642834
# Train Epoch : 2 | Batch Status : 58240/60000 (97%) | Loss : 0.351592
# Train Epoch : 2 | Batch Status : 58880/60000 (98%) | Loss : 0.421794
# Train Epoch : 2 | Batch Status : 59520/60000 (99%) | Loss : 0.280059
# Training time: 0m 6s
# ==================
# Test set: Average loss : 0.0065, Accuracy : 8752/10000(88%)
# Tesing time: 0m 7s
# Train Epoch : 3 | Batch Status : 0/60000 (0%) | Loss : 0.393256
# Train Epoch : 3 | Batch Status : 640/60000 (1%) | Loss : 0.359508
# Train Epoch : 3 | Batch Status : 1280/60000 (2%) | Loss : 0.571274
# Train Epoch : 3 | Batch Status : 1920/60000 (3%) | Loss : 0.337082
# Train Epoch : 3 | Batch Status : 2560/60000 (4%) | Loss : 0.293281
# Train Epoch : 3 | Batch Status : 3200/60000 (5%) | Loss : 0.370794
# Train Epoch : 3 | Batch Status : 3840/60000 (6%) | Loss : 0.515965
# Train Epoch : 3 | Batch Status : 4480/60000 (7%) | Loss : 0.315366
# Train Epoch : 3 | Batch Status : 5120/60000 (9%) | Loss : 0.516041
# Train Epoch : 3 | Batch Status : 5760/60000 (10%) | Loss : 0.281643
# Train Epoch : 3 | Batch Status : 6400/60000 (11%) | Loss : 0.245773
# Train Epoch : 3 | Batch Status : 7040/60000 (12%) | Loss : 0.702584
# Train Epoch : 3 | Batch Status : 7680/60000 (13%) | Loss : 0.459617
# Train Epoch : 3 | Batch Status : 8320/60000 (14%) | Loss : 0.482983
# Train Epoch : 3 | Batch Status : 8960/60000 (15%) | Loss : 0.395678
# Train Epoch : 3 | Batch Status : 9600/60000 (16%) | Loss : 0.441162
# Train Epoch : 3 | Batch Status : 10240/60000 (17%) | Loss : 0.433714
# Train Epoch : 3 | Batch Status : 10880/60000 (18%) | Loss : 0.392634
# Train Epoch : 3 | Batch Status : 11520/60000 (19%) | Loss : 0.420435
# Train Epoch : 3 | Batch Status : 12160/60000 (20%) | Loss : 0.417375
# Train Epoch : 3 | Batch Status : 12800/60000 (21%) | Loss : 0.249381
# Train Epoch : 3 | Batch Status : 13440/60000 (22%) | Loss : 0.227847
# Train Epoch : 3 | Batch Status : 14080/60000 (23%) | Loss : 0.240800
# Train Epoch : 3 | Batch Status : 14720/60000 (25%) | Loss : 0.360375
# Train Epoch : 3 | Batch Status : 15360/60000 (26%) | Loss : 0.194550
# Train Epoch : 3 | Batch Status : 16000/60000 (27%) | Loss : 0.340283
# Train Epoch : 3 | Batch Status : 16640/60000 (28%) | Loss : 0.479667
# Train Epoch : 3 | Batch Status : 17280/60000 (29%) | Loss : 0.413672
# Train Epoch : 3 | Batch Status : 17920/60000 (30%) | Loss : 0.378770
# Train Epoch : 3 | Batch Status : 18560/60000 (31%) | Loss : 0.400339
# Train Epoch : 3 | Batch Status : 19200/60000 (32%) | Loss : 0.314455
# Train Epoch : 3 | Batch Status : 19840/60000 (33%) | Loss : 0.346846
# Train Epoch : 3 | Batch Status : 20480/60000 (34%) | Loss : 0.431646
# Train Epoch : 3 | Batch Status : 21120/60000 (35%) | Loss : 0.304100
# Train Epoch : 3 | Batch Status : 21760/60000 (36%) | Loss : 0.333110
# Train Epoch : 3 | Batch Status : 22400/60000 (37%) | Loss : 0.356734
# Train Epoch : 3 | Batch Status : 23040/60000 (38%) | Loss : 0.327785
# Train Epoch : 3 | Batch Status : 23680/60000 (39%) | Loss : 0.326072
# Train Epoch : 3 | Batch Status : 24320/60000 (41%) | Loss : 0.607633
# Train Epoch : 3 | Batch Status : 24960/60000 (42%) | Loss : 0.478580
# Train Epoch : 3 | Batch Status : 25600/60000 (43%) | Loss : 0.311265
# Train Epoch : 3 | Batch Status : 26240/60000 (44%) | Loss : 0.479178
# Train Epoch : 3 | Batch Status : 26880/60000 (45%) | Loss : 0.361120
# Train Epoch : 3 | Batch Status : 27520/60000 (46%) | Loss : 0.491268
# Train Epoch : 3 | Batch Status : 28160/60000 (47%) | Loss : 0.345083
# Train Epoch : 3 | Batch Status : 28800/60000 (48%) | Loss : 0.289614
# Train Epoch : 3 | Batch Status : 29440/60000 (49%) | Loss : 0.399583
# Train Epoch : 3 | Batch Status : 30080/60000 (50%) | Loss : 0.244780
# Train Epoch : 3 | Batch Status : 30720/60000 (51%) | Loss : 0.500659
# Train Epoch : 3 | Batch Status : 31360/60000 (52%) | Loss : 0.338857
# Train Epoch : 3 | Batch Status : 32000/60000 (53%) | Loss : 0.266902
# Train Epoch : 3 | Batch Status : 32640/60000 (54%) | Loss : 0.332594
# Train Epoch : 3 | Batch Status : 33280/60000 (55%) | Loss : 0.365302
# Train Epoch : 3 | Batch Status : 33920/60000 (57%) | Loss : 0.247340
# Train Epoch : 3 | Batch Status : 34560/60000 (58%) | Loss : 0.308870
# Train Epoch : 3 | Batch Status : 35200/60000 (59%) | Loss : 0.370711
# Train Epoch : 3 | Batch Status : 35840/60000 (60%) | Loss : 0.443166
# Train Epoch : 3 | Batch Status : 36480/60000 (61%) | Loss : 0.540060
# Train Epoch : 3 | Batch Status : 37120/60000 (62%) | Loss : 0.298977
# Train Epoch : 3 | Batch Status : 37760/60000 (63%) | Loss : 0.302273
# Train Epoch : 3 | Batch Status : 38400/60000 (64%) | Loss : 0.238471
# Train Epoch : 3 | Batch Status : 39040/60000 (65%) | Loss : 0.189158
# Train Epoch : 3 | Batch Status : 39680/60000 (66%) | Loss : 0.564386
# Train Epoch : 3 | Batch Status : 40320/60000 (67%) | Loss : 0.328683
# Train Epoch : 3 | Batch Status : 40960/60000 (68%) | Loss : 0.502848
# Train Epoch : 3 | Batch Status : 41600/60000 (69%) | Loss : 0.292769
# Train Epoch : 3 | Batch Status : 42240/60000 (70%) | Loss : 0.466634
# Train Epoch : 3 | Batch Status : 42880/60000 (71%) | Loss : 0.178522
# Train Epoch : 3 | Batch Status : 43520/60000 (72%) | Loss : 0.667298
# Train Epoch : 3 | Batch Status : 44160/60000 (74%) | Loss : 0.136596
# Train Epoch : 3 | Batch Status : 44800/60000 (75%) | Loss : 0.619972
# Train Epoch : 3 | Batch Status : 45440/60000 (76%) | Loss : 0.418200
# Train Epoch : 3 | Batch Status : 46080/60000 (77%) | Loss : 0.319185
# Train Epoch : 3 | Batch Status : 46720/60000 (78%) | Loss : 0.311122
# Train Epoch : 3 | Batch Status : 47360/60000 (79%) | Loss : 0.511766
# Train Epoch : 3 | Batch Status : 48000/60000 (80%) | Loss : 0.304758
# Train Epoch : 3 | Batch Status : 48640/60000 (81%) | Loss : 0.200351
# Train Epoch : 3 | Batch Status : 49280/60000 (82%) | Loss : 0.332228
# Train Epoch : 3 | Batch Status : 49920/60000 (83%) | Loss : 0.324230
# Train Epoch : 3 | Batch Status : 50560/60000 (84%) | Loss : 0.543457
# Train Epoch : 3 | Batch Status : 51200/60000 (85%) | Loss : 0.369260
# Train Epoch : 3 | Batch Status : 51840/60000 (86%) | Loss : 0.165009
# Train Epoch : 3 | Batch Status : 52480/60000 (87%) | Loss : 0.415354
# Train Epoch : 3 | Batch Status : 53120/60000 (88%) | Loss : 0.341320
# Train Epoch : 3 | Batch Status : 53760/60000 (90%) | Loss : 0.393455
# Train Epoch : 3 | Batch Status : 54400/60000 (91%) | Loss : 0.184397
# Train Epoch : 3 | Batch Status : 55040/60000 (92%) | Loss : 0.265875
# Train Epoch : 3 | Batch Status : 55680/60000 (93%) | Loss : 0.219398
# Train Epoch : 3 | Batch Status : 56320/60000 (94%) | Loss : 0.261247
# Train Epoch : 3 | Batch Status : 56960/60000 (95%) | Loss : 0.461512
# Train Epoch : 3 | Batch Status : 57600/60000 (96%) | Loss : 0.206971
# Train Epoch : 3 | Batch Status : 58240/60000 (97%) | Loss : 0.298961
# Train Epoch : 3 | Batch Status : 58880/60000 (98%) | Loss : 0.492880
# Train Epoch : 3 | Batch Status : 59520/60000 (99%) | Loss : 0.261471
# Training time: 0m 6s
# ==================
# Test set: Average loss : 0.0047, Accuracy : 9116/10000(91%)
# Tesing time: 0m 7s
# Train Epoch : 4 | Batch Status : 0/60000 (0%) | Loss : 0.522499
# Train Epoch : 4 | Batch Status : 640/60000 (1%) | Loss : 0.192597
# Train Epoch : 4 | Batch Status : 1280/60000 (2%) | Loss : 0.245843
# Train Epoch : 4 | Batch Status : 1920/60000 (3%) | Loss : 0.187516
# Train Epoch : 4 | Batch Status : 2560/60000 (4%) | Loss : 0.180300
# Train Epoch : 4 | Batch Status : 3200/60000 (5%) | Loss : 0.290990
# Train Epoch : 4 | Batch Status : 3840/60000 (6%) | Loss : 0.116215
# Train Epoch : 4 | Batch Status : 4480/60000 (7%) | Loss : 0.200201
# Train Epoch : 4 | Batch Status : 5120/60000 (9%) | Loss : 0.627570
# Train Epoch : 4 | Batch Status : 5760/60000 (10%) | Loss : 0.414155
# Train Epoch : 4 | Batch Status : 6400/60000 (11%) | Loss : 0.280654
# Train Epoch : 4 | Batch Status : 7040/60000 (12%) | Loss : 0.232224
# Train Epoch : 4 | Batch Status : 7680/60000 (13%) | Loss : 0.367181
# Train Epoch : 4 | Batch Status : 8320/60000 (14%) | Loss : 0.335063
# Train Epoch : 4 | Batch Status : 8960/60000 (15%) | Loss : 0.171122
# Train Epoch : 4 | Batch Status : 9600/60000 (16%) | Loss : 0.168154
# Train Epoch : 4 | Batch Status : 10240/60000 (17%) | Loss : 0.326964
# Train Epoch : 4 | Batch Status : 10880/60000 (18%) | Loss : 0.239612
# Train Epoch : 4 | Batch Status : 11520/60000 (19%) | Loss : 0.349501
# Train Epoch : 4 | Batch Status : 12160/60000 (20%) | Loss : 0.362461
# Train Epoch : 4 | Batch Status : 12800/60000 (21%) | Loss : 0.300494
# Train Epoch : 4 | Batch Status : 13440/60000 (22%) | Loss : 0.323688
# Train Epoch : 4 | Batch Status : 14080/60000 (23%) | Loss : 0.188679
# Train Epoch : 4 | Batch Status : 14720/60000 (25%) | Loss : 0.199891
# Train Epoch : 4 | Batch Status : 15360/60000 (26%) | Loss : 0.219350
# Train Epoch : 4 | Batch Status : 16000/60000 (27%) | Loss : 0.218606
# Train Epoch : 4 | Batch Status : 16640/60000 (28%) | Loss : 0.333549
# Train Epoch : 4 | Batch Status : 17280/60000 (29%) | Loss : 0.417928
# Train Epoch : 4 | Batch Status : 17920/60000 (30%) | Loss : 0.169443
# Train Epoch : 4 | Batch Status : 18560/60000 (31%) | Loss : 0.207537
# Train Epoch : 4 | Batch Status : 19200/60000 (32%) | Loss : 0.206183
# Train Epoch : 4 | Batch Status : 19840/60000 (33%) | Loss : 0.423526
# Train Epoch : 4 | Batch Status : 20480/60000 (34%) | Loss : 0.234078
# Train Epoch : 4 | Batch Status : 21120/60000 (35%) | Loss : 0.330296
# Train Epoch : 4 | Batch Status : 21760/60000 (36%) | Loss : 0.186576
# Train Epoch : 4 | Batch Status : 22400/60000 (37%) | Loss : 0.262618
# Train Epoch : 4 | Batch Status : 23040/60000 (38%) | Loss : 0.198742
# Train Epoch : 4 | Batch Status : 23680/60000 (39%) | Loss : 0.146923
# Train Epoch : 4 | Batch Status : 24320/60000 (41%) | Loss : 0.274538
# Train Epoch : 4 | Batch Status : 24960/60000 (42%) | Loss : 0.243348
# Train Epoch : 4 | Batch Status : 25600/60000 (43%) | Loss : 0.184104
# Train Epoch : 4 | Batch Status : 26240/60000 (44%) | Loss : 0.225516
# Train Epoch : 4 | Batch Status : 26880/60000 (45%) | Loss : 0.276819
# Train Epoch : 4 | Batch Status : 27520/60000 (46%) | Loss : 0.211727
# Train Epoch : 4 | Batch Status : 28160/60000 (47%) | Loss : 0.227478
# Train Epoch : 4 | Batch Status : 28800/60000 (48%) | Loss : 0.212282
# Train Epoch : 4 | Batch Status : 29440/60000 (49%) | Loss : 0.354651
# Train Epoch : 4 | Batch Status : 30080/60000 (50%) | Loss : 0.102415
# Train Epoch : 4 | Batch Status : 30720/60000 (51%) | Loss : 0.293151
# Train Epoch : 4 | Batch Status : 31360/60000 (52%) | Loss : 0.339243
# Train Epoch : 4 | Batch Status : 32000/60000 (53%) | Loss : 0.233583
# Train Epoch : 4 | Batch Status : 32640/60000 (54%) | Loss : 0.256452
# Train Epoch : 4 | Batch Status : 33280/60000 (55%) | Loss : 0.252996
# Train Epoch : 4 | Batch Status : 33920/60000 (57%) | Loss : 0.438679
# Train Epoch : 4 | Batch Status : 34560/60000 (58%) | Loss : 0.172228
# Train Epoch : 4 | Batch Status : 35200/60000 (59%) | Loss : 0.317713
# Train Epoch : 4 | Batch Status : 35840/60000 (60%) | Loss : 0.168488
# Train Epoch : 4 | Batch Status : 36480/60000 (61%) | Loss : 0.196231
# Train Epoch : 4 | Batch Status : 37120/60000 (62%) | Loss : 0.193553
# Train Epoch : 4 | Batch Status : 37760/60000 (63%) | Loss : 0.291454
# Train Epoch : 4 | Batch Status : 38400/60000 (64%) | Loss : 0.161713
# Train Epoch : 4 | Batch Status : 39040/60000 (65%) | Loss : 0.227026
# Train Epoch : 4 | Batch Status : 39680/60000 (66%) | Loss : 0.242544
# Train Epoch : 4 | Batch Status : 40320/60000 (67%) | Loss : 0.395680
# Train Epoch : 4 | Batch Status : 40960/60000 (68%) | Loss : 0.229161
# Train Epoch : 4 | Batch Status : 41600/60000 (69%) | Loss : 0.387930
# Train Epoch : 4 | Batch Status : 42240/60000 (70%) | Loss : 0.235571
# Train Epoch : 4 | Batch Status : 42880/60000 (71%) | Loss : 0.270800
# Train Epoch : 4 | Batch Status : 43520/60000 (72%) | Loss : 0.287829
# Train Epoch : 4 | Batch Status : 44160/60000 (74%) | Loss : 0.379078
# Train Epoch : 4 | Batch Status : 44800/60000 (75%) | Loss : 0.139209
# Train Epoch : 4 | Batch Status : 45440/60000 (76%) | Loss : 0.190438
# Train Epoch : 4 | Batch Status : 46080/60000 (77%) | Loss : 0.350729
# Train Epoch : 4 | Batch Status : 46720/60000 (78%) | Loss : 0.259283
# Train Epoch : 4 | Batch Status : 47360/60000 (79%) | Loss : 0.186152
# Train Epoch : 4 | Batch Status : 48000/60000 (80%) | Loss : 0.464707
# Train Epoch : 4 | Batch Status : 48640/60000 (81%) | Loss : 0.169177
# Train Epoch : 4 | Batch Status : 49280/60000 (82%) | Loss : 0.201351
# Train Epoch : 4 | Batch Status : 49920/60000 (83%) | Loss : 0.141878
# Train Epoch : 4 | Batch Status : 50560/60000 (84%) | Loss : 0.328859
# Train Epoch : 4 | Batch Status : 51200/60000 (85%) | Loss : 0.190059
# Train Epoch : 4 | Batch Status : 51840/60000 (86%) | Loss : 0.135493
# Train Epoch : 4 | Batch Status : 52480/60000 (87%) | Loss : 0.191015
# Train Epoch : 4 | Batch Status : 53120/60000 (88%) | Loss : 0.339040
# Train Epoch : 4 | Batch Status : 53760/60000 (90%) | Loss : 0.160885
# Train Epoch : 4 | Batch Status : 54400/60000 (91%) | Loss : 0.179696
# Train Epoch : 4 | Batch Status : 55040/60000 (92%) | Loss : 0.158715
# Train Epoch : 4 | Batch Status : 55680/60000 (93%) | Loss : 0.307575
# Train Epoch : 4 | Batch Status : 56320/60000 (94%) | Loss : 0.145487
# Train Epoch : 4 | Batch Status : 56960/60000 (95%) | Loss : 0.359807
# Train Epoch : 4 | Batch Status : 57600/60000 (96%) | Loss : 0.154172
# Train Epoch : 4 | Batch Status : 58240/60000 (97%) | Loss : 0.131862
# Train Epoch : 4 | Batch Status : 58880/60000 (98%) | Loss : 0.174428
# Train Epoch : 4 | Batch Status : 59520/60000 (99%) | Loss : 0.436041
# Training time: 0m 6s
# ==================
# Test set: Average loss : 0.0038, Accuracy : 9293/10000(93%)
# Tesing time: 0m 7s
# Train Epoch : 5 | Batch Status : 0/60000 (0%) | Loss : 0.235329
# Train Epoch : 5 | Batch Status : 640/60000 (1%) | Loss : 0.132322
# Train Epoch : 5 | Batch Status : 1280/60000 (2%) | Loss : 0.137509
# Train Epoch : 5 | Batch Status : 1920/60000 (3%) | Loss : 0.201055
# Train Epoch : 5 | Batch Status : 2560/60000 (4%) | Loss : 0.311526
# Train Epoch : 5 | Batch Status : 3200/60000 (5%) | Loss : 0.170592
# Train Epoch : 5 | Batch Status : 3840/60000 (6%) | Loss : 0.320826
# Train Epoch : 5 | Batch Status : 4480/60000 (7%) | Loss : 0.193699
# Train Epoch : 5 | Batch Status : 5120/60000 (9%) | Loss : 0.100832
# Train Epoch : 5 | Batch Status : 5760/60000 (10%) | Loss : 0.148798
# Train Epoch : 5 | Batch Status : 6400/60000 (11%) | Loss : 0.285426
# Train Epoch : 5 | Batch Status : 7040/60000 (12%) | Loss : 0.267007
# Train Epoch : 5 | Batch Status : 7680/60000 (13%) | Loss : 0.123478
# Train Epoch : 5 | Batch Status : 8320/60000 (14%) | Loss : 0.407122
# Train Epoch : 5 | Batch Status : 8960/60000 (15%) | Loss : 0.200337
# Train Epoch : 5 | Batch Status : 9600/60000 (16%) | Loss : 0.228412
# Train Epoch : 5 | Batch Status : 10240/60000 (17%) | Loss : 0.222679
# Train Epoch : 5 | Batch Status : 10880/60000 (18%) | Loss : 0.198587
# Train Epoch : 5 | Batch Status : 11520/60000 (19%) | Loss : 0.298742
# Train Epoch : 5 | Batch Status : 12160/60000 (20%) | Loss : 0.231974
# Train Epoch : 5 | Batch Status : 12800/60000 (21%) | Loss : 0.381555
# Train Epoch : 5 | Batch Status : 13440/60000 (22%) | Loss : 0.255322
# Train Epoch : 5 | Batch Status : 14080/60000 (23%) | Loss : 0.359211
# Train Epoch : 5 | Batch Status : 14720/60000 (25%) | Loss : 0.075373
# Train Epoch : 5 | Batch Status : 15360/60000 (26%) | Loss : 0.238126
# Train Epoch : 5 | Batch Status : 16000/60000 (27%) | Loss : 0.363138
# Train Epoch : 5 | Batch Status : 16640/60000 (28%) | Loss : 0.252979
# Train Epoch : 5 | Batch Status : 17280/60000 (29%) | Loss : 0.130644
# Train Epoch : 5 | Batch Status : 17920/60000 (30%) | Loss : 0.205496
# Train Epoch : 5 | Batch Status : 18560/60000 (31%) | Loss : 0.252422
# Train Epoch : 5 | Batch Status : 19200/60000 (32%) | Loss : 0.252017
# Train Epoch : 5 | Batch Status : 19840/60000 (33%) | Loss : 0.188172
# Train Epoch : 5 | Batch Status : 20480/60000 (34%) | Loss : 0.152170
# Train Epoch : 5 | Batch Status : 21120/60000 (35%) | Loss : 0.363234
# Train Epoch : 5 | Batch Status : 21760/60000 (36%) | Loss : 0.266973
# Train Epoch : 5 | Batch Status : 22400/60000 (37%) | Loss : 0.113603
# Train Epoch : 5 | Batch Status : 23040/60000 (38%) | Loss : 0.225507
# Train Epoch : 5 | Batch Status : 23680/60000 (39%) | Loss : 0.320363
# Train Epoch : 5 | Batch Status : 24320/60000 (41%) | Loss : 0.189535
# Train Epoch : 5 | Batch Status : 24960/60000 (42%) | Loss : 0.096396
# Train Epoch : 5 | Batch Status : 25600/60000 (43%) | Loss : 0.163106
# Train Epoch : 5 | Batch Status : 26240/60000 (44%) | Loss : 0.218255
# Train Epoch : 5 | Batch Status : 26880/60000 (45%) | Loss : 0.197954
# Train Epoch : 5 | Batch Status : 27520/60000 (46%) | Loss : 0.135983
# Train Epoch : 5 | Batch Status : 28160/60000 (47%) | Loss : 0.280140
# Train Epoch : 5 | Batch Status : 28800/60000 (48%) | Loss : 0.319851
# Train Epoch : 5 | Batch Status : 29440/60000 (49%) | Loss : 0.287044
# Train Epoch : 5 | Batch Status : 30080/60000 (50%) | Loss : 0.115584
# Train Epoch : 5 | Batch Status : 30720/60000 (51%) | Loss : 0.123299
# Train Epoch : 5 | Batch Status : 31360/60000 (52%) | Loss : 0.175423
# Train Epoch : 5 | Batch Status : 32000/60000 (53%) | Loss : 0.239629
# Train Epoch : 5 | Batch Status : 32640/60000 (54%) | Loss : 0.215443
# Train Epoch : 5 | Batch Status : 33280/60000 (55%) | Loss : 0.197805
# Train Epoch : 5 | Batch Status : 33920/60000 (57%) | Loss : 0.232300
# Train Epoch : 5 | Batch Status : 34560/60000 (58%) | Loss : 0.206667
# Train Epoch : 5 | Batch Status : 35200/60000 (59%) | Loss : 0.105412
# Train Epoch : 5 | Batch Status : 35840/60000 (60%) | Loss : 0.250607
# Train Epoch : 5 | Batch Status : 36480/60000 (61%) | Loss : 0.116704
# Train Epoch : 5 | Batch Status : 37120/60000 (62%) | Loss : 0.307643
# Train Epoch : 5 | Batch Status : 37760/60000 (63%) | Loss : 0.114807
# Train Epoch : 5 | Batch Status : 38400/60000 (64%) | Loss : 0.272347
# Train Epoch : 5 | Batch Status : 39040/60000 (65%) | Loss : 0.245027
# Train Epoch : 5 | Batch Status : 39680/60000 (66%) | Loss : 0.201074
# Train Epoch : 5 | Batch Status : 40320/60000 (67%) | Loss : 0.199777
# Train Epoch : 5 | Batch Status : 40960/60000 (68%) | Loss : 0.271674
# Train Epoch : 5 | Batch Status : 41600/60000 (69%) | Loss : 0.088543
# Train Epoch : 5 | Batch Status : 42240/60000 (70%) | Loss : 0.217521
# Train Epoch : 5 | Batch Status : 42880/60000 (71%) | Loss : 0.267148
# Train Epoch : 5 | Batch Status : 43520/60000 (72%) | Loss : 0.185336
# Train Epoch : 5 | Batch Status : 44160/60000 (74%) | Loss : 0.126603
# Train Epoch : 5 | Batch Status : 44800/60000 (75%) | Loss : 0.060922
# Train Epoch : 5 | Batch Status : 45440/60000 (76%) | Loss : 0.288148
# Train Epoch : 5 | Batch Status : 46080/60000 (77%) | Loss : 0.160365
# Train Epoch : 5 | Batch Status : 46720/60000 (78%) | Loss : 0.248259
# Train Epoch : 5 | Batch Status : 47360/60000 (79%) | Loss : 0.151748
# Train Epoch : 5 | Batch Status : 48000/60000 (80%) | Loss : 0.142582
# Train Epoch : 5 | Batch Status : 48640/60000 (81%) | Loss : 0.300681
# Train Epoch : 5 | Batch Status : 49280/60000 (82%) | Loss : 0.104280
# Train Epoch : 5 | Batch Status : 49920/60000 (83%) | Loss : 0.184990
# Train Epoch : 5 | Batch Status : 50560/60000 (84%) | Loss : 0.079666
# Train Epoch : 5 | Batch Status : 51200/60000 (85%) | Loss : 0.124091
# Train Epoch : 5 | Batch Status : 51840/60000 (86%) | Loss : 0.145991
# Train Epoch : 5 | Batch Status : 52480/60000 (87%) | Loss : 0.107536
# Train Epoch : 5 | Batch Status : 53120/60000 (88%) | Loss : 0.242715
# Train Epoch : 5 | Batch Status : 53760/60000 (90%) | Loss : 0.188265
# Train Epoch : 5 | Batch Status : 54400/60000 (91%) | Loss : 0.072716
# Train Epoch : 5 | Batch Status : 55040/60000 (92%) | Loss : 0.168891
# Train Epoch : 5 | Batch Status : 55680/60000 (93%) | Loss : 0.191370
# Train Epoch : 5 | Batch Status : 56320/60000 (94%) | Loss : 0.107581
# Train Epoch : 5 | Batch Status : 56960/60000 (95%) | Loss : 0.226698
# Train Epoch : 5 | Batch Status : 57600/60000 (96%) | Loss : 0.178911
# Train Epoch : 5 | Batch Status : 58240/60000 (97%) | Loss : 0.219784
# Train Epoch : 5 | Batch Status : 58880/60000 (98%) | Loss : 0.402489
# Train Epoch : 5 | Batch Status : 59520/60000 (99%) | Loss : 0.100019
# Training time: 0m 6s
# ==================
# Test set: Average loss : 0.0031, Accuracy : 9430/10000(94%)
# Tesing time: 0m 7s
# Train Epoch : 6 | Batch Status : 0/60000 (0%) | Loss : 0.269400
# Train Epoch : 6 | Batch Status : 640/60000 (1%) | Loss : 0.089451
# Train Epoch : 6 | Batch Status : 1280/60000 (2%) | Loss : 0.072708
# Train Epoch : 6 | Batch Status : 1920/60000 (3%) | Loss : 0.165405
# Train Epoch : 6 | Batch Status : 2560/60000 (4%) | Loss : 0.065701
# Train Epoch : 6 | Batch Status : 3200/60000 (5%) | Loss : 0.130950
# Train Epoch : 6 | Batch Status : 3840/60000 (6%) | Loss : 0.269132
# Train Epoch : 6 | Batch Status : 4480/60000 (7%) | Loss : 0.276364
# Train Epoch : 6 | Batch Status : 5120/60000 (9%) | Loss : 0.248090
# Train Epoch : 6 | Batch Status : 5760/60000 (10%) | Loss : 0.147529
# Train Epoch : 6 | Batch Status : 6400/60000 (11%) | Loss : 0.134615
# Train Epoch : 6 | Batch Status : 7040/60000 (12%) | Loss : 0.218738
# Train Epoch : 6 | Batch Status : 7680/60000 (13%) | Loss : 0.082418
# Train Epoch : 6 | Batch Status : 8320/60000 (14%) | Loss : 0.165081
# Train Epoch : 6 | Batch Status : 8960/60000 (15%) | Loss : 0.146032
# Train Epoch : 6 | Batch Status : 9600/60000 (16%) | Loss : 0.156552
# Train Epoch : 6 | Batch Status : 10240/60000 (17%) | Loss : 0.242353
# Train Epoch : 6 | Batch Status : 10880/60000 (18%) | Loss : 0.107329
# Train Epoch : 6 | Batch Status : 11520/60000 (19%) | Loss : 0.123441
# Train Epoch : 6 | Batch Status : 12160/60000 (20%) | Loss : 0.276195
# Train Epoch : 6 | Batch Status : 12800/60000 (21%) | Loss : 0.124250
# Train Epoch : 6 | Batch Status : 13440/60000 (22%) | Loss : 0.045628
# Train Epoch : 6 | Batch Status : 14080/60000 (23%) | Loss : 0.136133
# Train Epoch : 6 | Batch Status : 14720/60000 (25%) | Loss : 0.258811
# Train Epoch : 6 | Batch Status : 15360/60000 (26%) | Loss : 0.101215
# Train Epoch : 6 | Batch Status : 16000/60000 (27%) | Loss : 0.176388
# Train Epoch : 6 | Batch Status : 16640/60000 (28%) | Loss : 0.123053
# Train Epoch : 6 | Batch Status : 17280/60000 (29%) | Loss : 0.371380
# Train Epoch : 6 | Batch Status : 17920/60000 (30%) | Loss : 0.196658
# Train Epoch : 6 | Batch Status : 18560/60000 (31%) | Loss : 0.098002
# Train Epoch : 6 | Batch Status : 19200/60000 (32%) | Loss : 0.113445
# Train Epoch : 6 | Batch Status : 19840/60000 (33%) | Loss : 0.277253
# Train Epoch : 6 | Batch Status : 20480/60000 (34%) | Loss : 0.099346
# Train Epoch : 6 | Batch Status : 21120/60000 (35%) | Loss : 0.106348
# Train Epoch : 6 | Batch Status : 21760/60000 (36%) | Loss : 0.084335
# Train Epoch : 6 | Batch Status : 22400/60000 (37%) | Loss : 0.174496
# Train Epoch : 6 | Batch Status : 23040/60000 (38%) | Loss : 0.197412
# Train Epoch : 6 | Batch Status : 23680/60000 (39%) | Loss : 0.252299
# Train Epoch : 6 | Batch Status : 24320/60000 (41%) | Loss : 0.183113
# Train Epoch : 6 | Batch Status : 24960/60000 (42%) | Loss : 0.105371
# Train Epoch : 6 | Batch Status : 25600/60000 (43%) | Loss : 0.166363
# Train Epoch : 6 | Batch Status : 26240/60000 (44%) | Loss : 0.156565
# Train Epoch : 6 | Batch Status : 26880/60000 (45%) | Loss : 0.135355
# Train Epoch : 6 | Batch Status : 27520/60000 (46%) | Loss : 0.190052
# Train Epoch : 6 | Batch Status : 28160/60000 (47%) | Loss : 0.127819
# Train Epoch : 6 | Batch Status : 28800/60000 (48%) | Loss : 0.106362
# Train Epoch : 6 | Batch Status : 29440/60000 (49%) | Loss : 0.189556
# Train Epoch : 6 | Batch Status : 30080/60000 (50%) | Loss : 0.071181
# Train Epoch : 6 | Batch Status : 30720/60000 (51%) | Loss : 0.477273
# Train Epoch : 6 | Batch Status : 31360/60000 (52%) | Loss : 0.293829
# Train Epoch : 6 | Batch Status : 32000/60000 (53%) | Loss : 0.235282
# Train Epoch : 6 | Batch Status : 32640/60000 (54%) | Loss : 0.145372
# Train Epoch : 6 | Batch Status : 33280/60000 (55%) | Loss : 0.087346
# Train Epoch : 6 | Batch Status : 33920/60000 (57%) | Loss : 0.285938
# Train Epoch : 6 | Batch Status : 34560/60000 (58%) | Loss : 0.231839
# Train Epoch : 6 | Batch Status : 35200/60000 (59%) | Loss : 0.302904
# Train Epoch : 6 | Batch Status : 35840/60000 (60%) | Loss : 0.095788
# Train Epoch : 6 | Batch Status : 36480/60000 (61%) | Loss : 0.232363
# Train Epoch : 6 | Batch Status : 37120/60000 (62%) | Loss : 0.108544
# Train Epoch : 6 | Batch Status : 37760/60000 (63%) | Loss : 0.081335
# Train Epoch : 6 | Batch Status : 38400/60000 (64%) | Loss : 0.360110
# Train Epoch : 6 | Batch Status : 39040/60000 (65%) | Loss : 0.161091
# Train Epoch : 6 | Batch Status : 39680/60000 (66%) | Loss : 0.318215
# Train Epoch : 6 | Batch Status : 40320/60000 (67%) | Loss : 0.079071
# Train Epoch : 6 | Batch Status : 40960/60000 (68%) | Loss : 0.164229
# Train Epoch : 6 | Batch Status : 41600/60000 (69%) | Loss : 0.094027
# Train Epoch : 6 | Batch Status : 42240/60000 (70%) | Loss : 0.073174
# Train Epoch : 6 | Batch Status : 42880/60000 (71%) | Loss : 0.167575
# Train Epoch : 6 | Batch Status : 43520/60000 (72%) | Loss : 0.144053
# Train Epoch : 6 | Batch Status : 44160/60000 (74%) | Loss : 0.248035
# Train Epoch : 6 | Batch Status : 44800/60000 (75%) | Loss : 0.223673
# Train Epoch : 6 | Batch Status : 45440/60000 (76%) | Loss : 0.076182
# Train Epoch : 6 | Batch Status : 46080/60000 (77%) | Loss : 0.105616
# Train Epoch : 6 | Batch Status : 46720/60000 (78%) | Loss : 0.182433
# Train Epoch : 6 | Batch Status : 47360/60000 (79%) | Loss : 0.206488
# Train Epoch : 6 | Batch Status : 48000/60000 (80%) | Loss : 0.240499
# Train Epoch : 6 | Batch Status : 48640/60000 (81%) | Loss : 0.231127
# Train Epoch : 6 | Batch Status : 49280/60000 (82%) | Loss : 0.124077
# Train Epoch : 6 | Batch Status : 49920/60000 (83%) | Loss : 0.079594
# Train Epoch : 6 | Batch Status : 50560/60000 (84%) | Loss : 0.068242
# Train Epoch : 6 | Batch Status : 51200/60000 (85%) | Loss : 0.269124
# Train Epoch : 6 | Batch Status : 51840/60000 (86%) | Loss : 0.257611
# Train Epoch : 6 | Batch Status : 52480/60000 (87%) | Loss : 0.156110
# Train Epoch : 6 | Batch Status : 53120/60000 (88%) | Loss : 0.111725
# Train Epoch : 6 | Batch Status : 53760/60000 (90%) | Loss : 0.101748
# Train Epoch : 6 | Batch Status : 54400/60000 (91%) | Loss : 0.100082
# Train Epoch : 6 | Batch Status : 55040/60000 (92%) | Loss : 0.128153
# Train Epoch : 6 | Batch Status : 55680/60000 (93%) | Loss : 0.117109
# Train Epoch : 6 | Batch Status : 56320/60000 (94%) | Loss : 0.117219
# Train Epoch : 6 | Batch Status : 56960/60000 (95%) | Loss : 0.179733
# Train Epoch : 6 | Batch Status : 57600/60000 (96%) | Loss : 0.092173
# Train Epoch : 6 | Batch Status : 58240/60000 (97%) | Loss : 0.121003
# Train Epoch : 6 | Batch Status : 58880/60000 (98%) | Loss : 0.107822
# Train Epoch : 6 | Batch Status : 59520/60000 (99%) | Loss : 0.302339
# Training time: 0m 6s
# ==================
# Test set: Average loss : 0.0024, Accuracy : 9560/10000(96%)
# Tesing time: 0m 7s
# Train Epoch : 7 | Batch Status : 0/60000 (0%) | Loss : 0.155026
# Train Epoch : 7 | Batch Status : 640/60000 (1%) | Loss : 0.124856
# Train Epoch : 7 | Batch Status : 1280/60000 (2%) | Loss : 0.183148
# Train Epoch : 7 | Batch Status : 1920/60000 (3%) | Loss : 0.192826
# Train Epoch : 7 | Batch Status : 2560/60000 (4%) | Loss : 0.162485
# Train Epoch : 7 | Batch Status : 3200/60000 (5%) | Loss : 0.187586
# Train Epoch : 7 | Batch Status : 3840/60000 (6%) | Loss : 0.089549
# Train Epoch : 7 | Batch Status : 4480/60000 (7%) | Loss : 0.073554
# Train Epoch : 7 | Batch Status : 5120/60000 (9%) | Loss : 0.073399
# Train Epoch : 7 | Batch Status : 5760/60000 (10%) | Loss : 0.136425
# Train Epoch : 7 | Batch Status : 6400/60000 (11%) | Loss : 0.063845
# Train Epoch : 7 | Batch Status : 7040/60000 (12%) | Loss : 0.086768
# Train Epoch : 7 | Batch Status : 7680/60000 (13%) | Loss : 0.132870
# Train Epoch : 7 | Batch Status : 8320/60000 (14%) | Loss : 0.150685
# Train Epoch : 7 | Batch Status : 8960/60000 (15%) | Loss : 0.362878
# Train Epoch : 7 | Batch Status : 9600/60000 (16%) | Loss : 0.244254
# Train Epoch : 7 | Batch Status : 10240/60000 (17%) | Loss : 0.040523
# Train Epoch : 7 | Batch Status : 10880/60000 (18%) | Loss : 0.083001
# Train Epoch : 7 | Batch Status : 11520/60000 (19%) | Loss : 0.063107
# Train Epoch : 7 | Batch Status : 12160/60000 (20%) | Loss : 0.069473
# Train Epoch : 7 | Batch Status : 12800/60000 (21%) | Loss : 0.258654
# Train Epoch : 7 | Batch Status : 13440/60000 (22%) | Loss : 0.149336
# Train Epoch : 7 | Batch Status : 14080/60000 (23%) | Loss : 0.133118
# Train Epoch : 7 | Batch Status : 14720/60000 (25%) | Loss : 0.244306
# Train Epoch : 7 | Batch Status : 15360/60000 (26%) | Loss : 0.186493
# Train Epoch : 7 | Batch Status : 16000/60000 (27%) | Loss : 0.050542
# Train Epoch : 7 | Batch Status : 16640/60000 (28%) | Loss : 0.122460
# Train Epoch : 7 | Batch Status : 17280/60000 (29%) | Loss : 0.173647
# Train Epoch : 7 | Batch Status : 17920/60000 (30%) | Loss : 0.082661
# Train Epoch : 7 | Batch Status : 18560/60000 (31%) | Loss : 0.075154
# Train Epoch : 7 | Batch Status : 19200/60000 (32%) | Loss : 0.043496
# Train Epoch : 7 | Batch Status : 19840/60000 (33%) | Loss : 0.163430
# Train Epoch : 7 | Batch Status : 20480/60000 (34%) | Loss : 0.160689
# Train Epoch : 7 | Batch Status : 21120/60000 (35%) | Loss : 0.087026
# Train Epoch : 7 | Batch Status : 21760/60000 (36%) | Loss : 0.052841
# Train Epoch : 7 | Batch Status : 22400/60000 (37%) | Loss : 0.278931
# Train Epoch : 7 | Batch Status : 23040/60000 (38%) | Loss : 0.038039
# Train Epoch : 7 | Batch Status : 23680/60000 (39%) | Loss : 0.133458
# Train Epoch : 7 | Batch Status : 24320/60000 (41%) | Loss : 0.050993
# Train Epoch : 7 | Batch Status : 24960/60000 (42%) | Loss : 0.157425
# Train Epoch : 7 | Batch Status : 25600/60000 (43%) | Loss : 0.043945
# Train Epoch : 7 | Batch Status : 26240/60000 (44%) | Loss : 0.097282
# Train Epoch : 7 | Batch Status : 26880/60000 (45%) | Loss : 0.080788
# Train Epoch : 7 | Batch Status : 27520/60000 (46%) | Loss : 0.095253
# Train Epoch : 7 | Batch Status : 28160/60000 (47%) | Loss : 0.193619
# Train Epoch : 7 | Batch Status : 28800/60000 (48%) | Loss : 0.109987
# Train Epoch : 7 | Batch Status : 29440/60000 (49%) | Loss : 0.264940
# Train Epoch : 7 | Batch Status : 30080/60000 (50%) | Loss : 0.248543
# Train Epoch : 7 | Batch Status : 30720/60000 (51%) | Loss : 0.038683
# Train Epoch : 7 | Batch Status : 31360/60000 (52%) | Loss : 0.073376
# Train Epoch : 7 | Batch Status : 32000/60000 (53%) | Loss : 0.155299
# Train Epoch : 7 | Batch Status : 32640/60000 (54%) | Loss : 0.076469
# Train Epoch : 7 | Batch Status : 33280/60000 (55%) | Loss : 0.121012
# Train Epoch : 7 | Batch Status : 33920/60000 (57%) | Loss : 0.193861
# Train Epoch : 7 | Batch Status : 34560/60000 (58%) | Loss : 0.137501
# Train Epoch : 7 | Batch Status : 35200/60000 (59%) | Loss : 0.100820
# Train Epoch : 7 | Batch Status : 35840/60000 (60%) | Loss : 0.352146
# Train Epoch : 7 | Batch Status : 36480/60000 (61%) | Loss : 0.111832
# Train Epoch : 7 | Batch Status : 37120/60000 (62%) | Loss : 0.209987
# Train Epoch : 7 | Batch Status : 37760/60000 (63%) | Loss : 0.164019
# Train Epoch : 7 | Batch Status : 38400/60000 (64%) | Loss : 0.239260
# Train Epoch : 7 | Batch Status : 39040/60000 (65%) | Loss : 0.080098
# Train Epoch : 7 | Batch Status : 39680/60000 (66%) | Loss : 0.242431
# Train Epoch : 7 | Batch Status : 40320/60000 (67%) | Loss : 0.156138
# Train Epoch : 7 | Batch Status : 40960/60000 (68%) | Loss : 0.331282
# Train Epoch : 7 | Batch Status : 41600/60000 (69%) | Loss : 0.148705
# Train Epoch : 7 | Batch Status : 42240/60000 (70%) | Loss : 0.041174
# Train Epoch : 7 | Batch Status : 42880/60000 (71%) | Loss : 0.160827
# Train Epoch : 7 | Batch Status : 43520/60000 (72%) | Loss : 0.054605
# Train Epoch : 7 | Batch Status : 44160/60000 (74%) | Loss : 0.045981
# Train Epoch : 7 | Batch Status : 44800/60000 (75%) | Loss : 0.136749
# Train Epoch : 7 | Batch Status : 45440/60000 (76%) | Loss : 0.175000
# Train Epoch : 7 | Batch Status : 46080/60000 (77%) | Loss : 0.130331
# Train Epoch : 7 | Batch Status : 46720/60000 (78%) | Loss : 0.053796
# Train Epoch : 7 | Batch Status : 47360/60000 (79%) | Loss : 0.081710
# Train Epoch : 7 | Batch Status : 48000/60000 (80%) | Loss : 0.252482
# Train Epoch : 7 | Batch Status : 48640/60000 (81%) | Loss : 0.066161
# Train Epoch : 7 | Batch Status : 49280/60000 (82%) | Loss : 0.109854
# Train Epoch : 7 | Batch Status : 49920/60000 (83%) | Loss : 0.136127
# Train Epoch : 7 | Batch Status : 50560/60000 (84%) | Loss : 0.058441
# Train Epoch : 7 | Batch Status : 51200/60000 (85%) | Loss : 0.249589
# Train Epoch : 7 | Batch Status : 51840/60000 (86%) | Loss : 0.054746
# Train Epoch : 7 | Batch Status : 52480/60000 (87%) | Loss : 0.242729
# Train Epoch : 7 | Batch Status : 53120/60000 (88%) | Loss : 0.130383
# Train Epoch : 7 | Batch Status : 53760/60000 (90%) | Loss : 0.215611
# Train Epoch : 7 | Batch Status : 54400/60000 (91%) | Loss : 0.050427
# Train Epoch : 7 | Batch Status : 55040/60000 (92%) | Loss : 0.260719
# Train Epoch : 7 | Batch Status : 55680/60000 (93%) | Loss : 0.075779
# Train Epoch : 7 | Batch Status : 56320/60000 (94%) | Loss : 0.029875
# Train Epoch : 7 | Batch Status : 56960/60000 (95%) | Loss : 0.164411
# Train Epoch : 7 | Batch Status : 57600/60000 (96%) | Loss : 0.029174
# Train Epoch : 7 | Batch Status : 58240/60000 (97%) | Loss : 0.043062
# Train Epoch : 7 | Batch Status : 58880/60000 (98%) | Loss : 0.083330
# Train Epoch : 7 | Batch Status : 59520/60000 (99%) | Loss : 0.058588
# Training time: 0m 6s
# ==================
# Test set: Average loss : 0.0020, Accuracy : 9610/10000(96%)
# Tesing time: 0m 7s
# Train Epoch : 8 | Batch Status : 0/60000 (0%) | Loss : 0.158541
# Train Epoch : 8 | Batch Status : 640/60000 (1%) | Loss : 0.067213
# Train Epoch : 8 | Batch Status : 1280/60000 (2%) | Loss : 0.079384
# Train Epoch : 8 | Batch Status : 1920/60000 (3%) | Loss : 0.080950
# Train Epoch : 8 | Batch Status : 2560/60000 (4%) | Loss : 0.078731
# Train Epoch : 8 | Batch Status : 3200/60000 (5%) | Loss : 0.286481
# Train Epoch : 8 | Batch Status : 3840/60000 (6%) | Loss : 0.058940
# Train Epoch : 8 | Batch Status : 4480/60000 (7%) | Loss : 0.137769
# Train Epoch : 8 | Batch Status : 5120/60000 (9%) | Loss : 0.178337
# Train Epoch : 8 | Batch Status : 5760/60000 (10%) | Loss : 0.036364
# Train Epoch : 8 | Batch Status : 6400/60000 (11%) | Loss : 0.295002
# Train Epoch : 8 | Batch Status : 7040/60000 (12%) | Loss : 0.186240
# Train Epoch : 8 | Batch Status : 7680/60000 (13%) | Loss : 0.130120
# Train Epoch : 8 | Batch Status : 8320/60000 (14%) | Loss : 0.156500
# Train Epoch : 8 | Batch Status : 8960/60000 (15%) | Loss : 0.019457
# Train Epoch : 8 | Batch Status : 9600/60000 (16%) | Loss : 0.104692
# Train Epoch : 8 | Batch Status : 10240/60000 (17%) | Loss : 0.078211
# Train Epoch : 8 | Batch Status : 10880/60000 (18%) | Loss : 0.183030
# Train Epoch : 8 | Batch Status : 11520/60000 (19%) | Loss : 0.028617
# Train Epoch : 8 | Batch Status : 12160/60000 (20%) | Loss : 0.084558
# Train Epoch : 8 | Batch Status : 12800/60000 (21%) | Loss : 0.184964
# Train Epoch : 8 | Batch Status : 13440/60000 (22%) | Loss : 0.088305
# Train Epoch : 8 | Batch Status : 14080/60000 (23%) | Loss : 0.123399
# Train Epoch : 8 | Batch Status : 14720/60000 (25%) | Loss : 0.050905
# Train Epoch : 8 | Batch Status : 15360/60000 (26%) | Loss : 0.050884
# Train Epoch : 8 | Batch Status : 16000/60000 (27%) | Loss : 0.062094
# Train Epoch : 8 | Batch Status : 16640/60000 (28%) | Loss : 0.084369
# Train Epoch : 8 | Batch Status : 17280/60000 (29%) | Loss : 0.030420
# Train Epoch : 8 | Batch Status : 17920/60000 (30%) | Loss : 0.191260
# Train Epoch : 8 | Batch Status : 18560/60000 (31%) | Loss : 0.131054
# Train Epoch : 8 | Batch Status : 19200/60000 (32%) | Loss : 0.178107
# Train Epoch : 8 | Batch Status : 19840/60000 (33%) | Loss : 0.076391
# Train Epoch : 8 | Batch Status : 20480/60000 (34%) | Loss : 0.142875
# Train Epoch : 8 | Batch Status : 21120/60000 (35%) | Loss : 0.117820
# Train Epoch : 8 | Batch Status : 21760/60000 (36%) | Loss : 0.141053
# Train Epoch : 8 | Batch Status : 22400/60000 (37%) | Loss : 0.036102
# Train Epoch : 8 | Batch Status : 23040/60000 (38%) | Loss : 0.081846
# Train Epoch : 8 | Batch Status : 23680/60000 (39%) | Loss : 0.141386
# Train Epoch : 8 | Batch Status : 24320/60000 (41%) | Loss : 0.064167
# Train Epoch : 8 | Batch Status : 24960/60000 (42%) | Loss : 0.129975
# Train Epoch : 8 | Batch Status : 25600/60000 (43%) | Loss : 0.040665
# Train Epoch : 8 | Batch Status : 26240/60000 (44%) | Loss : 0.083885
# Train Epoch : 8 | Batch Status : 26880/60000 (45%) | Loss : 0.053615
# Train Epoch : 8 | Batch Status : 27520/60000 (46%) | Loss : 0.131544
# Train Epoch : 8 | Batch Status : 28160/60000 (47%) | Loss : 0.037712
# Train Epoch : 8 | Batch Status : 28800/60000 (48%) | Loss : 0.046403
# Train Epoch : 8 | Batch Status : 29440/60000 (49%) | Loss : 0.148799
# Train Epoch : 8 | Batch Status : 30080/60000 (50%) | Loss : 0.087213
# Train Epoch : 8 | Batch Status : 30720/60000 (51%) | Loss : 0.075742
# Train Epoch : 8 | Batch Status : 31360/60000 (52%) | Loss : 0.127808
# Train Epoch : 8 | Batch Status : 32000/60000 (53%) | Loss : 0.127260
# Train Epoch : 8 | Batch Status : 32640/60000 (54%) | Loss : 0.085357
# Train Epoch : 8 | Batch Status : 33280/60000 (55%) | Loss : 0.219421
# Train Epoch : 8 | Batch Status : 33920/60000 (57%) | Loss : 0.116928
# Train Epoch : 8 | Batch Status : 34560/60000 (58%) | Loss : 0.118951
# Train Epoch : 8 | Batch Status : 35200/60000 (59%) | Loss : 0.080147
# Train Epoch : 8 | Batch Status : 35840/60000 (60%) | Loss : 0.121936
# Train Epoch : 8 | Batch Status : 36480/60000 (61%) | Loss : 0.231548
# Train Epoch : 8 | Batch Status : 37120/60000 (62%) | Loss : 0.081433
# Train Epoch : 8 | Batch Status : 37760/60000 (63%) | Loss : 0.198975
# Train Epoch : 8 | Batch Status : 38400/60000 (64%) | Loss : 0.052810
# Train Epoch : 8 | Batch Status : 39040/60000 (65%) | Loss : 0.096865
# Train Epoch : 8 | Batch Status : 39680/60000 (66%) | Loss : 0.131876
# Train Epoch : 8 | Batch Status : 40320/60000 (67%) | Loss : 0.023515
# Train Epoch : 8 | Batch Status : 40960/60000 (68%) | Loss : 0.107683
# Train Epoch : 8 | Batch Status : 41600/60000 (69%) | Loss : 0.129803
# Train Epoch : 8 | Batch Status : 42240/60000 (70%) | Loss : 0.136642
# Train Epoch : 8 | Batch Status : 42880/60000 (71%) | Loss : 0.072116
# Train Epoch : 8 | Batch Status : 43520/60000 (72%) | Loss : 0.059204
# Train Epoch : 8 | Batch Status : 44160/60000 (74%) | Loss : 0.191776
# Train Epoch : 8 | Batch Status : 44800/60000 (75%) | Loss : 0.220697
# Train Epoch : 8 | Batch Status : 45440/60000 (76%) | Loss : 0.090069
# Train Epoch : 8 | Batch Status : 46080/60000 (77%) | Loss : 0.040205
# Train Epoch : 8 | Batch Status : 46720/60000 (78%) | Loss : 0.190433
# Train Epoch : 8 | Batch Status : 47360/60000 (79%) | Loss : 0.064771
# Train Epoch : 8 | Batch Status : 48000/60000 (80%) | Loss : 0.127332
# Train Epoch : 8 | Batch Status : 48640/60000 (81%) | Loss : 0.093189
# Train Epoch : 8 | Batch Status : 49280/60000 (82%) | Loss : 0.115981
# Train Epoch : 8 | Batch Status : 49920/60000 (83%) | Loss : 0.153362
# Train Epoch : 8 | Batch Status : 50560/60000 (84%) | Loss : 0.145971
# Train Epoch : 8 | Batch Status : 51200/60000 (85%) | Loss : 0.045237
# Train Epoch : 8 | Batch Status : 51840/60000 (86%) | Loss : 0.103435
# Train Epoch : 8 | Batch Status : 52480/60000 (87%) | Loss : 0.117486
# Train Epoch : 8 | Batch Status : 53120/60000 (88%) | Loss : 0.088596
# Train Epoch : 8 | Batch Status : 53760/60000 (90%) | Loss : 0.019865
# Train Epoch : 8 | Batch Status : 54400/60000 (91%) | Loss : 0.114992
# Train Epoch : 8 | Batch Status : 55040/60000 (92%) | Loss : 0.052584
# Train Epoch : 8 | Batch Status : 55680/60000 (93%) | Loss : 0.035054
# Train Epoch : 8 | Batch Status : 56320/60000 (94%) | Loss : 0.035307
# Train Epoch : 8 | Batch Status : 56960/60000 (95%) | Loss : 0.100923
# Train Epoch : 8 | Batch Status : 57600/60000 (96%) | Loss : 0.168423
# Train Epoch : 8 | Batch Status : 58240/60000 (97%) | Loss : 0.260383
# Train Epoch : 8 | Batch Status : 58880/60000 (98%) | Loss : 0.044812
# Train Epoch : 8 | Batch Status : 59520/60000 (99%) | Loss : 0.087239
# Training time: 0m 6s
# ==================
# Test set: Average loss : 0.0018, Accuracy : 9647/10000(96%)
# Tesing time: 0m 7s
# Train Epoch : 9 | Batch Status : 0/60000 (0%) | Loss : 0.195160
# Train Epoch : 9 | Batch Status : 640/60000 (1%) | Loss : 0.095275
# Train Epoch : 9 | Batch Status : 1280/60000 (2%) | Loss : 0.054821
# Train Epoch : 9 | Batch Status : 1920/60000 (3%) | Loss : 0.230091
# Train Epoch : 9 | Batch Status : 2560/60000 (4%) | Loss : 0.064163
# Train Epoch : 9 | Batch Status : 3200/60000 (5%) | Loss : 0.040772
# Train Epoch : 9 | Batch Status : 3840/60000 (6%) | Loss : 0.043861
# Train Epoch : 9 | Batch Status : 4480/60000 (7%) | Loss : 0.103192
# Train Epoch : 9 | Batch Status : 5120/60000 (9%) | Loss : 0.095814
# Train Epoch : 9 | Batch Status : 5760/60000 (10%) | Loss : 0.119754
# Train Epoch : 9 | Batch Status : 6400/60000 (11%) | Loss : 0.034928
# Train Epoch : 9 | Batch Status : 7040/60000 (12%) | Loss : 0.036514
# Train Epoch : 9 | Batch Status : 7680/60000 (13%) | Loss : 0.216151
# Train Epoch : 9 | Batch Status : 8320/60000 (14%) | Loss : 0.019096
# Train Epoch : 9 | Batch Status : 8960/60000 (15%) | Loss : 0.165004
# Train Epoch : 9 | Batch Status : 9600/60000 (16%) | Loss : 0.074729
# Train Epoch : 9 | Batch Status : 10240/60000 (17%) | Loss : 0.139125
# Train Epoch : 9 | Batch Status : 10880/60000 (18%) | Loss : 0.147328
# Train Epoch : 9 | Batch Status : 11520/60000 (19%) | Loss : 0.028556
# Train Epoch : 9 | Batch Status : 12160/60000 (20%) | Loss : 0.140751
# Train Epoch : 9 | Batch Status : 12800/60000 (21%) | Loss : 0.073611
# Train Epoch : 9 | Batch Status : 13440/60000 (22%) | Loss : 0.043900
# Train Epoch : 9 | Batch Status : 14080/60000 (23%) | Loss : 0.049662
# Train Epoch : 9 | Batch Status : 14720/60000 (25%) | Loss : 0.225437
# Train Epoch : 9 | Batch Status : 15360/60000 (26%) | Loss : 0.059668
# Train Epoch : 9 | Batch Status : 16000/60000 (27%) | Loss : 0.058220
# Train Epoch : 9 | Batch Status : 16640/60000 (28%) | Loss : 0.109387
# Train Epoch : 9 | Batch Status : 17280/60000 (29%) | Loss : 0.078681
# Train Epoch : 9 | Batch Status : 17920/60000 (30%) | Loss : 0.051832
# Train Epoch : 9 | Batch Status : 18560/60000 (31%) | Loss : 0.162065
# Train Epoch : 9 | Batch Status : 19200/60000 (32%) | Loss : 0.186351
# Train Epoch : 9 | Batch Status : 19840/60000 (33%) | Loss : 0.160059
# Train Epoch : 9 | Batch Status : 20480/60000 (34%) | Loss : 0.014260
# Train Epoch : 9 | Batch Status : 21120/60000 (35%) | Loss : 0.142889
# Train Epoch : 9 | Batch Status : 21760/60000 (36%) | Loss : 0.047886
# Train Epoch : 9 | Batch Status : 22400/60000 (37%) | Loss : 0.053096
# Train Epoch : 9 | Batch Status : 23040/60000 (38%) | Loss : 0.108154
# Train Epoch : 9 | Batch Status : 23680/60000 (39%) | Loss : 0.079508
# Train Epoch : 9 | Batch Status : 24320/60000 (41%) | Loss : 0.136681
# Train Epoch : 9 | Batch Status : 24960/60000 (42%) | Loss : 0.093848
# Train Epoch : 9 | Batch Status : 25600/60000 (43%) | Loss : 0.033502
# Train Epoch : 9 | Batch Status : 26240/60000 (44%) | Loss : 0.119176
# Train Epoch : 9 | Batch Status : 26880/60000 (45%) | Loss : 0.040376
# Train Epoch : 9 | Batch Status : 27520/60000 (46%) | Loss : 0.158410
# Train Epoch : 9 | Batch Status : 28160/60000 (47%) | Loss : 0.195161
# Train Epoch : 9 | Batch Status : 28800/60000 (48%) | Loss : 0.059860
# Train Epoch : 9 | Batch Status : 29440/60000 (49%) | Loss : 0.063284
# Train Epoch : 9 | Batch Status : 30080/60000 (50%) | Loss : 0.025579
# Train Epoch : 9 | Batch Status : 30720/60000 (51%) | Loss : 0.081612
# Train Epoch : 9 | Batch Status : 31360/60000 (52%) | Loss : 0.115739
# Train Epoch : 9 | Batch Status : 32000/60000 (53%) | Loss : 0.046111
# Train Epoch : 9 | Batch Status : 32640/60000 (54%) | Loss : 0.137593
# Train Epoch : 9 | Batch Status : 33280/60000 (55%) | Loss : 0.061069
# Train Epoch : 9 | Batch Status : 33920/60000 (57%) | Loss : 0.057121
# Train Epoch : 9 | Batch Status : 34560/60000 (58%) | Loss : 0.038830
# Train Epoch : 9 | Batch Status : 35200/60000 (59%) | Loss : 0.123638
# Train Epoch : 9 | Batch Status : 35840/60000 (60%) | Loss : 0.100561
# Train Epoch : 9 | Batch Status : 36480/60000 (61%) | Loss : 0.060517
# Train Epoch : 9 | Batch Status : 37120/60000 (62%) | Loss : 0.025777
# Train Epoch : 9 | Batch Status : 37760/60000 (63%) | Loss : 0.102324
# Train Epoch : 9 | Batch Status : 38400/60000 (64%) | Loss : 0.027846
# Train Epoch : 9 | Batch Status : 39040/60000 (65%) | Loss : 0.053952
# Train Epoch : 9 | Batch Status : 39680/60000 (66%) | Loss : 0.053730
# Train Epoch : 9 | Batch Status : 40320/60000 (67%) | Loss : 0.034768
# Train Epoch : 9 | Batch Status : 40960/60000 (68%) | Loss : 0.179619
# Train Epoch : 9 | Batch Status : 41600/60000 (69%) | Loss : 0.056629
# Train Epoch : 9 | Batch Status : 42240/60000 (70%) | Loss : 0.083520
# Train Epoch : 9 | Batch Status : 42880/60000 (71%) | Loss : 0.100831
# Train Epoch : 9 | Batch Status : 43520/60000 (72%) | Loss : 0.080960
# Train Epoch : 9 | Batch Status : 44160/60000 (74%) | Loss : 0.221450
# Train Epoch : 9 | Batch Status : 44800/60000 (75%) | Loss : 0.055079
# Train Epoch : 9 | Batch Status : 45440/60000 (76%) | Loss : 0.178185
# Train Epoch : 9 | Batch Status : 46080/60000 (77%) | Loss : 0.042768
# Train Epoch : 9 | Batch Status : 46720/60000 (78%) | Loss : 0.142930
# Train Epoch : 9 | Batch Status : 47360/60000 (79%) | Loss : 0.101375
# Train Epoch : 9 | Batch Status : 48000/60000 (80%) | Loss : 0.076886
# Train Epoch : 9 | Batch Status : 48640/60000 (81%) | Loss : 0.151984
# Train Epoch : 9 | Batch Status : 49280/60000 (82%) | Loss : 0.120418
# Train Epoch : 9 | Batch Status : 49920/60000 (83%) | Loss : 0.038453
# Train Epoch : 9 | Batch Status : 50560/60000 (84%) | Loss : 0.061227
# Train Epoch : 9 | Batch Status : 51200/60000 (85%) | Loss : 0.169353
# Train Epoch : 9 | Batch Status : 51840/60000 (86%) | Loss : 0.093229
# Train Epoch : 9 | Batch Status : 52480/60000 (87%) | Loss : 0.171994
# Train Epoch : 9 | Batch Status : 53120/60000 (88%) | Loss : 0.057459
# Train Epoch : 9 | Batch Status : 53760/60000 (90%) | Loss : 0.126962
# Train Epoch : 9 | Batch Status : 54400/60000 (91%) | Loss : 0.144889
# Train Epoch : 9 | Batch Status : 55040/60000 (92%) | Loss : 0.098027
# Train Epoch : 9 | Batch Status : 55680/60000 (93%) | Loss : 0.138498
# Train Epoch : 9 | Batch Status : 56320/60000 (94%) | Loss : 0.089227
# Train Epoch : 9 | Batch Status : 56960/60000 (95%) | Loss : 0.095132
# Train Epoch : 9 | Batch Status : 57600/60000 (96%) | Loss : 0.057268
# Train Epoch : 9 | Batch Status : 58240/60000 (97%) | Loss : 0.299632
# Train Epoch : 9 | Batch Status : 58880/60000 (98%) | Loss : 0.058827
# Train Epoch : 9 | Batch Status : 59520/60000 (99%) | Loss : 0.053851
# Training time: 0m 6s
# ==================
# Test set: Average loss : 0.0017, Accuracy : 9678/10000(97%)
# Tesing time: 0m 7s
# Total time : 0m  7s
# Model was trained on cuda!
